# %%
import re

# %%
#use of search and match

text = "This is a good day"

if re.search("good", text): # returns a bolean

    print("wonderful")
else:
    print("more wonderful")
# Out:
# wonderful
